# %%
import pandas as pd

df_demo = pd.read_csv("../data/raw/df_final_demo.txt", delimiter="\,")
df_demo
# Out:
# /var/folders/y1/9ww9qd857d59r9rnwfvnykh40000gn/T/ipykernel_4703/1303569942.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_demo = pd.read_csv("../data/raw/df_final_demo.txt", delimiter="\,")
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# ...

# %%
df_experiment = pd.read_csv("../data/raw/df_final_experiment_clients.txt", delimiter="\,")
df_experiment
# Out:
# /var/folders/y1/9ww9qd857d59r9rnwfvnykh40000gn/T/ipykernel_4703/1924881312.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_experiment = pd.read_csv("../data/raw/df_final_experiment_clients.txt", delimiter="\,")
#        client_id Variation
# 0        9988021      Test
# 1        8320017      Test
# 2        4033851   Control
# 3        1982004      Test
# 4        9294070   Control
# ...          ...       ...
# 70604    2443347       NaN
# 70605    8788427       NaN
# 70606     266828       NaN
# 70607    1266421       NaN
# 70608    9895983       NaN
#
# [70609 rows x 2 columns]

# %%
df_web_data_1 = pd.read_csv("../data/raw/df_final_web_data_pt_1.txt", delimiter="\,")
df_web_data_1
# Out:
# /var/folders/y1/9ww9qd857d59r9rnwfvnykh40000gn/T/ipykernel_4703/1466253258.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_web_data_1 = pd.read_csv("../data/raw/df_final_web_data_pt_1.txt", delimiter="\,")
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 343136    2443347  465784886_73090545671  136329900_10529659391_316129
# ...

# %%
df_web_data_2 = pd.read_csv("../data/raw/df_final_web_data_pt_2.txt", delimiter="\,")
df_web_data_2
# Out:
# /var/folders/y1/9ww9qd857d59r9rnwfvnykh40000gn/T/ipykernel_4703/3579792391.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   df_web_data_2 = pd.read_csv("../data/raw/df_final_web_data_pt_2.txt", delimiter="\,")
#         client_id             visitor_id                      visit_id  \
# 0          763412  601952081_10457207388  397475557_40440946728_419634
# 1         6019349  442094451_91531546617  154620534_35331068705_522317
# 2         6019349  442094451_91531546617  154620534_35331068705_522317
# 3         6019349  442094451_91531546617  154620534_35331068705_522317
# 4         6019349  442094451_91531546617  154620534_35331068705_522317
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# ...

# %%
df_web_data = pd.concat([df_web_data_1, df_web_data_2], axis=0)
df_web_data
# Out:
#         client_id             visitor_id                      visit_id  \
# 0         9988021   580560515_7732621733  781255054_21935453173_531117
# 1         9988021   580560515_7732621733  781255054_21935453173_531117
# 2         9988021   580560515_7732621733  781255054_21935453173_531117
# 3         9988021   580560515_7732621733  781255054_21935453173_531117
# 4         9988021   580560515_7732621733  781255054_21935453173_531117
# ...           ...                    ...                           ...
# 412259    9668240   388766751_9038881013   922267647_3096648104_968866
# 412260    9668240   388766751_9038881013   922267647_3096648104_968866
# 412261    9668240   388766751_9038881013   922267647_3096648104_968866
# 412262    9668240   388766751_9038881013   922267647_3096648104_968866
# 412263     674799  947159805_81558194550   86152093_47511127657_716022
#
#        process_step            date_time
# 0            step_3  2017-04-17 15:27:07
# ...

# %%
merged_df_demo_experiment = pd.merge(df_demo, df_experiment, on='client_id')
merged_df_demo_experiment
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 70604    7993686             4.0              56.0      38.5     U        3.0
# 70605    8981690            12.0             148.0      31.0     M        2.0
# 70606     333913            16.0             198.0      61.5     F        2.0
# 70607    1573142            21.0             255.0      68.0     M        3.0
# 70608    5602139            21.0             254.0      59.5     F        3.0
#
# ...

# %%
merged_df_demo_experiment_clean = merged_df_demo_experiment.dropna(subset=['Variation'])
merged_df_demo_experiment_clean
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50495    1780858            21.0             262.0      68.5     M        3.0
# 50496    6967120            21.0             260.0      68.5     M        3.0
# 50497    5826160            20.0             249.0      56.5     F        2.0
# 50498    8739285            19.0             229.0      69.5     F        2.0
# 50499    7468138            18.0             222.0      61.0     F        3.0
#
# ...

# %%
merged_df_demo_experiment_clean = merged_df_demo_experiment_clean.dropna(subset=['clnt_age'])
merged_df_demo_experiment_clean
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        2304905             7.0              94.0      58.0     U        2.0
# 2        1439522             5.0              64.0      32.0     U        2.0
# 3        1562045            16.0             198.0      49.0     M        2.0
# 4        5126305            12.0             145.0      33.0     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 50495    1780858            21.0             262.0      68.5     M        3.0
# 50496    6967120            21.0             260.0      68.5     M        3.0
# 50497    5826160            20.0             249.0      56.5     F        2.0
# 50498    8739285            19.0             229.0      69.5     F        2.0
# 50499    7468138            18.0             222.0      61.0     F        3.0
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(merged_df_demo_experiment_clean['clnt_age'], bins=20, kde=True)
plt.title("Age Distribution of Clients")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean['bal'], bins=20, kde=True)
plt.title("Balance in accounts of Clients")
plt.show()

# %%
merged_df_demo_experiment_clean.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  5.048700e+04    50487.000000      50487.000000  50487.000000
# mean   5.006180e+06       12.031810        150.416365     47.319795
# std    2.877445e+06        6.860326         81.945403     15.518616
# min    5.550000e+02        2.000000         33.000000     17.000000
# 25%    2.515688e+06        6.000000         82.000000     33.500000
# 50%    5.025043e+06       11.000000        136.000000     48.000000
# 75%    7.477922e+06       16.000000        192.000000     59.500000
# max    9.999832e+06       55.000000        669.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  50487.000000  5.048700e+04  50487.000000   50487.000000
# mean       2.254580  1.495168e+05      3.093272       6.131856
# std        0.533675  3.020390e+05      2.188009       2.175441
# min        1.000000  2.378944e+04      0.000000       3.000000
# ...

# %%
# Overall
#The average client age on the test group is 47 years old, the minimum is 17 and the maximum is 96. 
#The average client holds approximately 2.25 accounts (minimum of 1 and maximum of 7) and holds an average balance of 149,516.8 in all accounts (minimum of 23,789.44 and maximum of 16,320,040).
#In average the clients have been with Vanguard for 12.03 years or 150.41 months (maximum of 55 or 669 and minimum of 2 or 33).

# %%
merged_df_demo_experiment_clean_test = merged_df_demo_experiment_clean[merged_df_demo_experiment_clean['Variation'] == "Test"]
merged_df_demo_experiment_clean_test = merged_df_demo_experiment_clean_test.reset_index(drop=True)
merged_df_demo_experiment_clean_test
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0         836976             6.0              73.0      60.5     U        2.0
# 1        1439522             5.0              64.0      32.0     U        2.0
# 2        1562045            16.0             198.0      49.0     M        2.0
# 3         388801            30.0             361.0      57.5     M        5.0
# 4        8198645            15.0             189.0      54.5     F        2.0
# ...          ...             ...               ...       ...   ...        ...
# 26956     501496            23.0             281.0      35.0     F        2.0
# 26957    1780858            21.0             262.0      68.5     M        3.0
# 26958    5826160            20.0             249.0      56.5     F        2.0
# 26959    8739285            19.0             229.0      69.5     F        2.0
# 26960    7468138            18.0             222.0      61.0     F        3.0
#
# ...

# %%
merged_df_demo_experiment_clean_test.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  2.696100e+04    26961.000000      26961.000000  26961.000000
# mean   4.999639e+06       11.982901        149.852899     47.163922
# std    2.877510e+06        6.844947         81.783390     15.514461
# min    5.550000e+02        2.000000         33.000000     17.000000
# 25%    2.516570e+06        6.000000         82.000000     33.500000
# 50%    5.025928e+06       11.000000        134.000000     47.500000
# 75%    7.470213e+06       15.000000        191.000000     59.500000
# max    9.999832e+06       55.000000        669.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  26961.000000  2.696100e+04  26961.000000   26961.000000
# mean       2.249917  1.489626e+05      3.061941       6.101851
# std        0.529335  3.073737e+05      2.190590       2.177119
# min        1.000000  2.378944e+04      0.000000       3.000000
# ...

# %%
# Test Group
#The average client age on the test group is 47 years old, the minimum is 17 and the maximum is 96. 
#The average client holds approximately 2.25 accounts (minimum of 1 and maximum of 7) and holds an average balance of 148,962.6 in all accounts (minimum of 23,789.44 and maximum of 16,320,040).
#In average the clients have been with Vanguard for 11.98 years or 149.85 months (maximum of 55 or 669 and minimum of 2 or 33).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(merged_df_demo_experiment_clean_test['clnt_age'], bins=20, kde=True)
plt.title("Age Distribution of Clients")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_test['bal'], bins=20, kde=True)
plt.title("Balance in accounts of Clients")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_test['num_accts'], bins=20, kde=True)
plt.title("Number of Accounts per Client")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_test['clnt_tenure_yr'], bins=20, kde=True)
plt.title("Tenure Years - Test")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_test['clnt_tenure_mnth'], bins=20, kde=True)
plt.title("Tenure Months - Test")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_test['gendr'], bins=20, kde=True)
plt.title("Gender - Test")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_test['calls_6_mnth'], bins=20, kde=True)
plt.title("Calls past 6 months - Test")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_test['logons_6_mnth'], bins=20, kde=True)
plt.title("Logons past 6 months - Test")
plt.show()

# %%
merged_df_demo_experiment_clean_control = merged_df_demo_experiment_clean[merged_df_demo_experiment_clean['Variation'] == "Control"]
merged_df_demo_experiment_clean_control= merged_df_demo_experiment_clean_control.reset_index(drop=True)
merged_df_demo_experiment_clean_control
# Out:
#        client_id  clnt_tenure_yr  clnt_tenure_mnth  clnt_age gendr  num_accts  \
# 0        2304905             7.0              94.0      58.0     U        2.0
# 1        5126305            12.0             145.0      33.0     F        2.0
# 2        3727881             5.0              71.0      30.5     U        2.0
# 3         272934             5.0              66.0      58.5     U        2.0
# 4         285619            30.0             369.0      67.5     M        2.0
# ...          ...             ...               ...       ...   ...        ...
# 23521    6662941             7.0              84.0      36.0     F        2.0
# 23522    2787512            23.0             283.0      48.0     F        3.0
# 23523    9932367            23.0             280.0      57.0     F        2.0
# 23524    4079649            23.0             276.0      62.5     M        3.0
# 23525    6967120            21.0             260.0      68.5     M        3.0
#
# ...

# %%
merged_df_demo_experiment_clean_control.describe()
# Out:
#           client_id  clnt_tenure_yr  clnt_tenure_mnth      clnt_age  \
# count  2.352600e+04    23526.000000      23526.000000  23526.000000
# mean   5.013676e+06       12.087860        151.062102     47.498427
# std    2.877414e+06        6.877626         82.127663     15.521781
# min    1.028000e+03        2.000000         33.000000     17.000000
# 25%    2.515177e+06        6.000000         82.000000     33.500000
# 50%    5.023832e+06       11.000000        137.000000     48.500000
# 75%    7.483638e+06       16.000000        192.000000     60.000000
# max    9.998921e+06       55.000000        669.000000     96.000000
#
#           num_accts           bal  calls_6_mnth  logons_6_mnth
# count  23526.000000  2.352600e+04  23526.000000   23526.000000
# mean       2.259925  1.501519e+05      3.129176       6.166242
# std        0.538568  2.958124e+05      2.184541       2.173053
# min        2.000000  2.378961e+04      0.000000       3.000000
# ...

# %%
#Control group
#The average client age on the control group is 47 years old, the minimum is 17 and the maximum is 96. 
#The average client holds approximately 2.26 accounts (minimum of 1 and maximum of 7) and holds an average balance of 150,151.9 in all accounts (minimum of 23,789.44 and maximum of 16,320,040).
#In average the clients have been with Vanguard for 12.09 years or 151.06 months (maximum of 55 or 669 and minimum of 2 or 33).

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.histplot(merged_df_demo_experiment_clean_control['clnt_age'], bins=20, kde=True)
plt.title("Age Distribution of Clients - Control")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_control['bal'], bins=20, kde=True)
plt.title("Balance in accounts of Clients - Control")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_control['num_accts'], bins=20, kde=True)
plt.title("Number of Accounts per Client - Control")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_control['clnt_tenure_yr'], bins=20, kde=True)
plt.title("Tenure Years - Control")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_control['clnt_tenure_mnth'], bins=20, kde=True)
plt.title("Tenure Months - Control")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_control['gendr'], bins=20, kde=True)
plt.title("Gender - Control")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_control['calls_6_mnth'], bins=20, kde=True)
plt.title("Calls past 6 months - Control")
plt.show()

# %%
sns.histplot(merged_df_demo_experiment_clean_control['logons_6_mnth'], bins=20, kde=True)
plt.title("Logons past 6 months - Control")
plt.show()

# %%
merged_df_experiment_web_data = pd.merge(df_experiment, df_web_data, on='client_id')
merged_df_experiment_web_data.head(30)
# Out:
#     client_id Variation             visitor_id                      visit_id  \
# 0     9988021      Test   580560515_7732621733  781255054_21935453173_531117
# 1     9988021      Test   580560515_7732621733  781255054_21935453173_531117
# 2     9988021      Test   580560515_7732621733  781255054_21935453173_531117
# 3     9988021      Test   580560515_7732621733  781255054_21935453173_531117
# 4     9988021      Test   580560515_7732621733  781255054_21935453173_531117
# 5     9988021      Test   580560515_7732621733  781255054_21935453173_531117
# 6     9988021      Test   580560515_7732621733  781255054_21935453173_531117
# 7     9988021      Test   580560515_7732621733  781255054_21935453173_531117
# 8     9988021      Test   580560515_7732621733  219729223_42518459208_211914
# 9     9988021      Test   580560515_7732621733  219729223_42518459208_211914
# 10    9988021      Test   580560515_7732621733  219729223_42518459208_211914
# ...

# %%
merged_df_experiment_web_data_clean = merged_df_experiment_web_data.dropna(subset=['Variation'])

# %%
merged_df_experiment_web_data_clean.shape
# Out:
# (321309, 6)

# %%
variation_per_visitor = merged_df_experiment_web_data_clean.groupby("visitor_id")["Variation"].nunique()
dual_visitors = variation_per_visitor[variation_per_visitor == 2].index
dw_dual = merged_df_experiment_web_data_clean[merged_df_experiment_web_data_clean["visitor_id"].isin(dual_visitors)].copy()

# %%
variation_per_visitor = merged_df_experiment_web_data_clean.groupby("visitor_id")["Variation"].nunique()
variation_per_visitor.sort_values(ascending=False)
# Out:
# visitor_id
# 275094252_28070777384    2
# 1738850_35364551433      2
# 489537091_37607083854    2
# 865240682_80882863295    2
# 739324800_32877575794    2
#                         ..
# 398044028_91938220377    1
# 398048918_67621555670    1
# 398098733_26052978573    1
# 398108759_33552466384    1
# 999998529_89539814462    1
# Name: Variation, Length: 56011, dtype: int64

# %%
dual_visitors = variation_per_visitor[variation_per_visitor == 2].index
dual_visitors
# Out:
# Index(['100636834_70620124872', '101002710_46550496480',
#        '105986634_15115236135', '123678861_93517709373',
#        '124364695_72848638784', '125249697_1426097618',
#        '129784163_53998921269', '136361015_51931191096',
#        '13858321_69002501216', '143038172_18564060779',
#        ...
#        '958989901_59795798277', '959657282_41264437824',
#        '96089498_16066779499', '972190267_89053808634',
#        '982616761_11732633016', '989197874_24115340213',
#        '993860627_38915998531', '994556188_95260212644',
#        '995658764_57249134716', '998389409_35306819556'],
#       dtype='object', name='visitor_id', length=185)

# %%
merged_df_experiment_web_data_clean = merged_df_experiment_web_data_clean[~merged_df_experiment_web_data_clean["visitor_id"].isin(dual_visitors)]

# %%
merged_df_experiment_web_data_clean['date_time'] = pd.to_datetime(merged_df_experiment_web_data_clean['date_time'])
merged_df_experiment_web_data_clean = merged_df_experiment_web_data_clean[(merged_df_experiment_web_data_clean['date_time'] >= pd.to_datetime("2017-03-15 00:00:00")) & (merged_df_experiment_web_data_clean['date_time'] < pd.to_datetime("2017-06-20 23:59:59"))]
merged_df_experiment_web_data_clean
# Out:
#         client_id Variation             visitor_id  \
# 0         9988021      Test   580560515_7732621733
# 1         9988021      Test   580560515_7732621733
# 2         9988021      Test   580560515_7732621733
# 3         9988021      Test   580560515_7732621733
# 4         9988021      Test   580560515_7732621733
# ...           ...       ...                    ...
# 321304    6334360      Test  629124187_65258232847
# 321305    6334360      Test  629124187_65258232847
# 321306    6334360      Test  629124187_65258232847
# 321307    6334360      Test  629124187_65258232847
# 321308    6334360      Test  629124187_65258232847
#
#                             visit_id process_step           date_time
# 0       781255054_21935453173_531117       step_3 2017-04-17 15:27:07
# 1       781255054_21935453173_531117       step_2 2017-04-17 15:26:51
# 2       781255054_21935453173_531117       step_3 2017-04-17 15:19:22
# ...

# %%
merged_df_experiment_web_data_clean.to_csv("..\data\clean\df_final_experiment_web_data_clean.csv")

# %%
#Overall
merged_df_experiment_web_data_clean_start_confirm = merged_df_experiment_web_data_clean[merged_df_experiment_web_data_clean['process_step'].isin(["start", "confirm"])]
merged_df_experiment_web_data_clean_start_confirm
# Out:
#         client_id Variation             visitor_id  \
# 7         9988021      Test   580560515_7732621733
# 8         9988021      Test   580560515_7732621733
# 9         9988021      Test   580560515_7732621733
# 10        9988021      Test   580560515_7732621733
# 11        9988021      Test   580560515_7732621733
# ...           ...       ...                    ...
# 321294    7230446      Test  301456995_82370441715
# 321295    5230357      Test  832474317_11880812098
# 321299    5230357      Test  832474317_11880812098
# 321300    6334360      Test  629124187_65258232847
# 321308    6334360      Test  629124187_65258232847
#
#                             visit_id process_step           date_time
# 7       781255054_21935453173_531117        start 2017-04-17 15:16:22
# 8       219729223_42518459208_211914        start 2017-04-12 18:54:43
# 9       219729223_42518459208_211914        start 2017-04-12 18:38:42
# ...

# %%
merged_df_experiment_web_data_clean[merged_df_experiment_web_data_clean['visit_id']=='781255054_21935453173_531117'].sort_values(by="date_time")
# Out:
#    client_id Variation            visitor_id                      visit_id  \
# 7    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 6    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 5    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 4    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 3    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 2    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 1    9988021      Test  580560515_7732621733  781255054_21935453173_531117
# 0    9988021      Test  580560515_7732621733  781255054_21935453173_531117
#
#   process_step           date_time
# 7        start 2017-04-17 15:16:22
# 6       step_1 2017-04-17 15:17:01
# 5       step_2 2017-04-17 15:17:15
# 4       step_3 2017-04-17 15:18:04
# 3       step_2 2017-04-17 15:19:13
# 2       step_3 2017-04-17 15:19:22
# 1       step_2 2017-04-17 15:26:51
# ...

# %%
#Overall - completion rate
started = merged_df_experiment_web_data_clean_start_confirm[merged_df_experiment_web_data_clean_start_confirm['process_step'] == "start"]["visit_id"].nunique()
started
# Out:
# 63651

# %%
confirm = merged_df_experiment_web_data_clean_start_confirm[merged_df_experiment_web_data_clean_start_confirm['process_step'] == "confirm"]["visit_id"].nunique()
confirm
# Out:
# 37442

# %%
#Overall - completion rate - 58.82%
completion_rate_overall = confirm / started

print(f"Completion Rate: {(completion_rate_overall*100):.2f}%")
# Out:
# Completion Rate: 58.82%

# %%
#Test - completion rate
merged_df_experiment_web_data_clean_test = merged_df_experiment_web_data_clean[merged_df_experiment_web_data_clean['Variation'] == "Test"]
merged_df_experiment_web_data_clean_test
# Out:
#         client_id Variation             visitor_id  \
# 0         9988021      Test   580560515_7732621733
# 1         9988021      Test   580560515_7732621733
# 2         9988021      Test   580560515_7732621733
# 3         9988021      Test   580560515_7732621733
# 4         9988021      Test   580560515_7732621733
# ...           ...       ...                    ...
# 321304    6334360      Test  629124187_65258232847
# 321305    6334360      Test  629124187_65258232847
# 321306    6334360      Test  629124187_65258232847
# 321307    6334360      Test  629124187_65258232847
# 321308    6334360      Test  629124187_65258232847
#
#                             visit_id process_step           date_time
# 0       781255054_21935453173_531117       step_3 2017-04-17 15:27:07
# 1       781255054_21935453173_531117       step_2 2017-04-17 15:26:51
# 2       781255054_21935453173_531117       step_3 2017-04-17 15:19:22
# ...

# %%
merged_df_experiment_web_data_clean_test_start_confirm = merged_df_experiment_web_data_clean_test[merged_df_experiment_web_data_clean_test['process_step'].isin(["start", "confirm"])]
merged_df_experiment_web_data_clean_test_start_confirm
# Out:
#         client_id Variation             visitor_id  \
# 7         9988021      Test   580560515_7732621733
# 8         9988021      Test   580560515_7732621733
# 9         9988021      Test   580560515_7732621733
# 10        9988021      Test   580560515_7732621733
# 11        9988021      Test   580560515_7732621733
# ...           ...       ...                    ...
# 321294    7230446      Test  301456995_82370441715
# 321295    5230357      Test  832474317_11880812098
# 321299    5230357      Test  832474317_11880812098
# 321300    6334360      Test  629124187_65258232847
# 321308    6334360      Test  629124187_65258232847
#
#                             visit_id process_step           date_time
# 7       781255054_21935453173_531117        start 2017-04-17 15:16:22
# 8       219729223_42518459208_211914        start 2017-04-12 18:54:43
# 9       219729223_42518459208_211914        start 2017-04-12 18:38:42
# ...

# %%
started_test = merged_df_experiment_web_data_clean_test_start_confirm[merged_df_experiment_web_data_clean_test_start_confirm['process_step'] == "start"]["visit_id"].nunique()
started_test
# Out:
# 32954

# %%
confirm_test = merged_df_experiment_web_data_clean_test_start_confirm[merged_df_experiment_web_data_clean_test_start_confirm['process_step'] == "confirm"]["visit_id"].nunique()
confirm_test
# Out:
# 21557

# %%
#Test - completion rate - 65.42%
completion_rate_test = confirm_test / started_test

print(f"Completion Rate - Test: {(completion_rate_test*100):.2f}%")
# Out:
# Completion Rate - Test: 65.42%

# %%
#Control - completion rate
merged_df_experiment_web_data_clean_control = merged_df_experiment_web_data_clean[merged_df_experiment_web_data_clean['Variation'] == "Control"]
merged_df_experiment_web_data_clean_control
# Out:
#         client_id Variation             visitor_id  \
# 20        4033851   Control  762728880_76361333336
# 21        4033851   Control  762728880_76361333336
# 22        4033851   Control  762728880_76361333336
# 23        4033851   Control  762728880_76361333336
# 24        4033851   Control  762728880_76361333336
# ...           ...       ...                    ...
# 321265     393005   Control  238199953_33257685972
# 321266    2908510   Control  814969699_90652851448
# 321267    2908510   Control  814969699_90652851448
# 321268    2908510   Control  814969699_90652851448
# 321269    2908510   Control  814969699_90652851448
#
#                             visit_id process_step           date_time
# 20      949661017_22392791362_127391      confirm 2017-04-05 12:29:03
# 21      949661017_22392791362_127391      confirm 2017-04-05 12:29:01
# 22      949661017_22392791362_127391      confirm 2017-04-05 12:28:52
# ...

# %%
merged_df_experiment_web_data_clean_control_start_confirm = merged_df_experiment_web_data_clean_control[merged_df_experiment_web_data_clean_control['process_step'].isin(["start", "confirm"])]
merged_df_experiment_web_data_clean_control_start_confirm
# Out:
#         client_id Variation             visitor_id  \
# 20        4033851   Control  762728880_76361333336
# 21        4033851   Control  762728880_76361333336
# 22        4033851   Control  762728880_76361333336
# 26        4033851   Control  762728880_76361333336
# 34        4033851   Control  762728880_76361333336
# ...           ...       ...                    ...
# 321255     393005   Control  238199953_33257685972
# 321259     393005   Control  238199953_33257685972
# 321265     393005   Control  238199953_33257685972
# 321266    2908510   Control  814969699_90652851448
# 321269    2908510   Control  814969699_90652851448
#
#                             visit_id process_step           date_time
# 20      949661017_22392791362_127391      confirm 2017-04-05 12:29:03
# 21      949661017_22392791362_127391      confirm 2017-04-05 12:29:01
# 22      949661017_22392791362_127391      confirm 2017-04-05 12:28:52
# ...

# %%
#Control - completion rate
started_control = merged_df_experiment_web_data_clean_control_start_confirm[merged_df_experiment_web_data_clean_control_start_confirm['process_step'] == "start"]["visit_id"].nunique()
started_control
# Out:
# 30697

# %%
confirm_control = merged_df_experiment_web_data_clean_control_start_confirm[merged_df_experiment_web_data_clean_control_start_confirm['process_step'] == "confirm"]["visit_id"].nunique()
confirm_control
# Out:
# 15885

# %%
#Control - completion rate - 51.75%
completion_rate_control = confirm_control / started_control

print(f"Completion Rate - Control: {(completion_rate_control*100):.2f}%")
# Out:
# Completion Rate - Control: 51.75%

# %%
completion_rates_dic = {"completion_rate_overall": completion_rate_overall, "completion_rate_test": completion_rate_test, "completion_rate_control": completion_rate_control}
completion_rates_df = pd.DataFrame([completion_rates_dic])
completion_rates_df
# Out:
#    completion_rate_overall  completion_rate_test  completion_rate_control
# 0                 0.588239              0.654154                 0.517477

# %%
#Hypothesis

#H0: mean_completion_time_new <= mean_completion_time_old
#H1: mean_completion_time_new > mean_completion_time_old

#significance level(alpha) = 0.05

# %%
alpha = 0.05

# %%
print(completion_rate_control)
print(completion_rate_test)
print(completion_rate_overall)
print(started_control)
print(started_test)
# Out:
# 0.5174772779098935
# 0.6541542756569764
# 0.5882389907464141
# 30697
# 32954

# %%
# Hypothesis
# H0: completion_rate_test >= completion_rate_control + 0.05
# H1: completion_rate_test < completion_rate_control + 0.05

# H0: completion_rate_test - completion_rate_control >= 0.05
# H1: completion_rate_test - completion_rate_control < 0.05

# %%
import math
z = ((completion_rate_test-completion_rate_control)-0.05)/math.sqrt(((completion_rate_overall*(1-completion_rate_overall))*((1/(started_test))+((1/(started_control))))))
z
# Out:
# 22.20259651355574

# %%
merged_df_experiment_web_data_clean_test = merged_df_experiment_web_data_clean_test.sort_values(by=["client_id", "visitor_id", "visit_id", "date_time"], ascending=[True, True, True, True])
merged_df_experiment_web_data_clean_test
# Out:
#         client_id Variation             visitor_id  \
# 94261         555      Test  402506806_56087378777
# 94260         555      Test  402506806_56087378777
# 94259         555      Test  402506806_56087378777
# 94258         555      Test  402506806_56087378777
# 94257         555      Test  402506806_56087378777
# ...           ...       ...                    ...
# 140278    9999729      Test  843385170_36953471821
# 140277    9999729      Test  843385170_36953471821
# 140276    9999729      Test  843385170_36953471821
# 14818     9999832      Test  145538019_54444341400
# 14817     9999832      Test  145538019_54444341400
#
#                             visit_id process_step           date_time
# 94261   637149525_38041617439_716659        start 2017-04-15 12:57:56
# 94260   637149525_38041617439_716659       step_1 2017-04-15 12:58:03
# 94259   637149525_38041617439_716659       step_2 2017-04-15 12:58:35
# ...

# %%
merged_df_experiment_web_data_clean_control = merged_df_experiment_web_data_clean_control.sort_values(by=["client_id", "visitor_id", "visit_id", "date_time"], ascending=[True, True, True, True])
merged_df_experiment_web_data_clean_control
# Out:
#         client_id Variation             visitor_id  \
# 173012       1028   Control   42237450_62128060588
# 173011       1028   Control   42237450_62128060588
# 173010       1028   Control   42237450_62128060588
# 173009       1028   Control   42237450_62128060588
# 173008       1028   Control   42237450_62128060588
# ...           ...       ...                    ...
# 156311    9998346   Control  292425655_16607136645
# 156308    9998346   Control  292425655_16607136645
# 156309    9998346   Control  292425655_16607136645
# 156310    9998346   Control  292425655_16607136645
# 155808    9998921   Control  960034051_85687824805
#
#                             visit_id process_step           date_time
# 173012  557292053_87239438319_391157        start 2017-04-08 18:51:28
# 173011  557292053_87239438319_391157       step_1 2017-04-08 18:52:17
# 173010  557292053_87239438319_391157       step_1 2017-04-08 18:53:20
# ...

# %%
merged_df_experiment_web_data_clean_test_555 = merged_df_experiment_web_data_clean_test[merged_df_experiment_web_data_clean_test["client_id"]==555]

# %%
merged_df_experiment_web_data_clean_test_555
# Out:
#        client_id Variation             visitor_id  \
# 94261        555      Test  402506806_56087378777
# 94260        555      Test  402506806_56087378777
# 94259        555      Test  402506806_56087378777
# 94258        555      Test  402506806_56087378777
# 94257        555      Test  402506806_56087378777
#
#                            visit_id process_step           date_time
# 94261  637149525_38041617439_716659        start 2017-04-15 12:57:56
# 94260  637149525_38041617439_716659       step_1 2017-04-15 12:58:03
# 94259  637149525_38041617439_716659       step_2 2017-04-15 12:58:35
# 94258  637149525_38041617439_716659       step_3 2017-04-15 13:00:14
# 94257  637149525_38041617439_716659      confirm 2017-04-15 13:00:34

# %%
pd.DataFrame(merged_df_experiment_web_data_clean_test_555.groupby('date_time')['process_step'])
# Out:
#                     0                                                  1
# 0 2017-04-15 12:57:56   94261    start
# Name: process_step, dtype: object
# 1 2017-04-15 12:58:03  94260    step_1
# Name: process_step, dtype: object
# 2 2017-04-15 12:58:35  94259    step_2
# Name: process_step, dtype: object
# 3 2017-04-15 13:00:14  94258    step_3
# Name: process_step, dtype: object
# 4 2017-04-15 13:00:34  94257    confirm
# Name: process_step, dtype: ob...

# %%
durations = pd.DataFrame(merged_df_experiment_web_data_clean_test_555.groupby('process_step')['date_time'])

print(durations)
# Out:
#          0                                                  1
# 0  confirm  94257   2017-04-15 13:00:34
# Name: date_time, d...
# 1    start  94261   2017-04-15 12:57:56
# Name: date_time, d...
# 2   step_1  94260   2017-04-15 12:58:03
# Name: date_time, d...
# 3   step_2  94259   2017-04-15 12:58:35
# Name: date_time, d...
# 4   step_3  94258   2017-04-15 13:00:14
# Name: date_time, d...

# %%
merged_df_experiment_web_data_clean_test_555[merged_df_experiment_web_data_clean_test_555["process_step"]

merged_df_experiment_web_data_clean[(merged_df_experiment_web_data_clean['date_time'] >= pd.to_datetime("2017-03-15 00:00:00"))
# Out:
#   Cell In[70], line 3
#     merged_df_experiment_web_data_clean[(merged_df_experiment_web_data_clean['date_time'] >= pd.to_datetime("2017-03-15 00:00:00"))
#                                        ^
# SyntaxError: '[' was never closed
